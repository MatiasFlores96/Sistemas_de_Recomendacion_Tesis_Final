# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(15, 7))

#KNN-User
plt.step([0.0939,0.1799,0.2579,0.3179,0.3676,0.4056,0.44,0.4703,0.4938,0.5146], [0.7934,0.7975,0.7995,0.7907,0.7835,0.7758,0.771,0.7695,0.767,0.7644], linewidth=3, label='KNN-User')
plt.plot([0.0939,0.1799,0.2579,0.3179,0.3676,0.4056,0.44,0.4703,0.4938,0.5146], [0.7934,0.7975,0.7995,0.7907,0.7835,0.7758,0.771,0.7695,0.767,0.7644], 'C0o', alpha=0.05)

#KNN-Item
plt.step([0.0704,0.1367,0.1989,0.2523,0.2971,0.3391,0.373,0.4001,0.4238,0.4439], [0.6607,0.6639,0.6582,0.6616,0.6586,0.6573,0.6531,0.6499,0.6502,0.6497], linewidth=3, label='KNN-Item')
plt.plot([0.0704,0.1367,0.1989,0.2523,0.2971,0.3391,0.373,0.4001,0.4238,0.4439], [0.6607,0.6639,0.6582,0.6616,0.6586,0.6573,0.6531,0.6499,0.6502,0.6497], 'C1o', alpha=0.05)

#SVD-Funk
plt.step([0.0978,0.18,0.2459,0.3055,0.3522,0.3913,0.4272,0.456,0.4786,0.4983], [0.8246,0.8221,0.8093,0.8023,0.793,0.7842,0.779,0.7761,0.7724,0.7717], linewidth=3, label='SVD-Funk')
plt.plot([0.0978,0.18,0.2459,0.3055,0.3522,0.3913,0.4272,0.456,0.4786,0.4983], [0.8246,0.8221,0.8093,0.8023,0.793,0.7842,0.779,0.7761,0.7724,0.7717], 'C2o', alpha=0.05)

#Random
plt.step([0.0753,0.1405,0.194,0.234,0.2737,0.2992,0.3188,0.3366,0.3501,0.3607], [0.6426,0.6525,0.6522,0.6497,0.6506,0.648,0.6473,0.6488,0.6491,0.6472], linewidth=3, label='Random')
plt.plot([0.0753,0.1405,0.194,0.234,0.2737,0.2992,0.3188,0.3366,0.3501,0.3607], [0.6426,0.6525,0.6522,0.6497,0.6506,0.648,0.6473,0.6488,0.6491,0.6472], 'C3o', alpha=0.05)

#PMF
plt.step([0.0956,0.1723,0.2351,0.2876,0.3292,0.3631,0.39,0.4133,0.4323,0.4489], [0.8131,0.8115,0.8025,0.7978,0.789,0.7857,0.7794,0.7752,0.7722,0.7707], linewidth=3, label='PMF')
plt.plot([0.0956,0.1723,0.2351,0.2876,0.3292,0.3631,0.39,0.4133,0.4323,0.4489], [0.8131,0.8115,0.8025,0.7978,0.789,0.7857,0.7794,0.7752,0.7722,0.7707], 'C4o', alpha=0.05)

#NMF
plt.step([0.0887,0.1568,0.2124,0.2646,0.3068,0.3413,0.3696,0.3925,0.4112,0.4275], [0.7607,0.7557,0.747,0.7475,0.7464,0.7466,0.746,0.7434,0.7416,0.7411], linewidth=3, label='NMF')
plt.plot([0.0887,0.1568,0.2124,0.2646,0.3068,0.3413,0.3696,0.3925,0.4112,0.4275], [0.7607,0.7557,0.747,0.7475,0.7464,0.7466,0.746,0.7434,0.7416,0.7411], 'C5o', alpha=0.05)

#Content
plt.step([0.084,0.1539,0.2147,0.2689,0.3169,0.3584,0.3931,0.4217,0.4451,0.4653], [0.759,0.7459,0.7339,0.7311,0.7273,0.7248,0.7223,0.7184,0.7151,0.7124], linewidth=3, label='Content')
plt.plot([0.084,0.1539,0.2147,0.2689,0.3169,0.3584,0.3931,0.4217,0.4451,0.4653], [0.759,0.7459,0.7339,0.7311,0.7273,0.7248,0.7223,0.7184,0.7151,0.7124], 'C6o', alpha=0.05)

plt.xlim(0, 0.55)
plt.ylim(0.63, 0.83)

plt.title(" Grafico Precision-Recall", fontsize=22)
plt.ylabel("Precision", fontsize=16)
plt.xlabel("Recall", fontsize=16)

plt.legend()
